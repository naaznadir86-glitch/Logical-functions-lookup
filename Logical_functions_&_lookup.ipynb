# %%
##Logical functions and lookup

# %% [markdown]
# #1. Write a formula to check if the marks in cell B2 are greater than or equal to 40.If yes "PASS" , otherwise "Fail".
# #Ans. IF(B2>=40,"PASS", "FAIL")

# %% [markdown]
# #2. A company gives a bonus if sales are above 40,000 and attendance is greater than or equal to 90%.Write A formula to calculate whether employee will get a bonus or not.
# #Ans.AND CONDITION
#  AND(B2>40,000 , C2>=90%)
#
#  If(AND(B2>40,000 , C2>90%) , "Yes" ,"No")

# %% [markdown]
# #3. Write A nested IF formula.
# If marks in B2=>90 = "A",=>75 ="B", =>50 ="C" ,otherwise "Fail"
# #Ans. If(B2=>90, "A" , B2=>75, "B" , B2=>50, "C", "FAIL"

# %% [markdown]
# #4.Find the department of employee ID=E103.WHICH LOOKUP FUNCTION USED AND WHY
# #Ans. Vlookup function will be used
